# %% [markdown]
# # SFDA_scraping project

# %% [markdown]
# - Step 1: get list of drugIds (6000 of them)
# - Step 2: for each drugId, get the drug information from https://sdi.sfda.gov.sa/Home/Result?drugId=X

# %%
#!pip install ipywidgets --upgrade
#!pip install tqdm --upgrade

import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# # Step 1:
# get list of drugIds (6000 of them)

# %%
base_url = "https://sdi.sfda.gov.sa/Home/AdvancedSearch"

# %%
# # only needed once - comment out after running
# drug_ids = []
# # scrape the drug IDs from the website
# for page_number in range(1, 551):  # 551 pages
#     url = base_url + "?page=" + str(page_number)
#     print("Page", page_number, url)

#     web_response = requests.get(url)
#     soup = BeautifulSoup(web_response.content, "html.parser")

#     links = soup.find_all("a", href=True)

#     for link in links:
#         href = link["href"]
#         if href.startswith("/Home/Result?drugId="):
#             drug_id = href.split("drugId=")[-1]
#             drug_ids.append(drug_id)

#     print("Length of Drug IDs so far", len(drug_ids))

# # Save the drug IDs to a CSV file
# drug_ids_df = pd.DataFrame(drug_ids, columns=["SFDA Drug ID"])
# drug_ids_df.to_csv("drug_ids.csv", index=False)
# print("Drug IDs saved to drug_ids.csv")
# print(drug_ids)

# %%
# load the drug IDs from the CSV file
drug_ids = []
drug_ids_df = pd.read_csv("drug_ids.csv")
drug_ids = drug_ids_df["SFDA Drug ID"].tolist()
print("Loaded", len(drug_ids), "Drug IDs")
# Out:
# Loaded 8250 Drug IDs

# %% [markdown]
# # Step 2:
# for each drugId, get the drug information from https://sdi.sfda.gov.sa/Home/Result?drugId=X

# %%
# List of fields to extract
fields = {
    "رقم التسجيل": "Registration Number",
    "سنة التسجيل": "Registration Year",
    "الاسم التجاري": "Brand Name",
    "الاسم العلمي": "Generic Name",
    "التركيز": "Strength",
    "وحدة التركيز": "Unit",
    "طريقة الإستعمال": "Route of Administration",
    "الشكل الصيدلاني": "Dosage Form",
    "حجم العبوة": "Package Size",
    "انواع العبوات": "Package Types",
    "طريقة الصرف": "Dispensing Method",
    "حالة المراقبة": "Monitoring Status",
    "نوع الدواء": "Drug Type",
    "مدة الصلاحية بالأشهر": "Shelf Life (Months)",
    "شروط التخزين": "Storage Conditions",
    "سعر الجمهور بالريال": "Public Price (SAR)",
    "المصنع": "Manufacturer",
    "الوكيل": "Agent",
    "الشركة المسوقة": "Marketing Company",
}

# %%
drug_page_base_url = "https://sdi.sfda.gov.sa/Home/Result?drugId="

# %%
# Function to extract text by field label
def get_field_value(soup, label_text):
    label = soup.find("label", string=label_text)
    if label:
        value_div = label.find_next("div", class_="form-line")
        if value_div:
            return value_div.text.strip()
    return None


def get_drug_info(drug_id):
    url = drug_page_base_url + str(drug_id)

    # Send a GET request to the URL
    web_response = requests.get(url)
    soup = BeautifulSoup(web_response.content, "html.parser")

    # Extract the data
    data = {fields[field]: get_field_value(soup, field) for field in fields}
    # add drug ID and URL
    data["SFDA Drug URL"] = url
    data["SFDA Drug ID"] = drug_id
    return data

# %%
# List to store data for all drugs
all_drugs_data = []

# load drug data from the excel file
all_drugs_data_df = pd.read_excel("drug_info.xlsx")
all_drugs_data = all_drugs_data_df.to_dict("records")
print("Loaded", len(all_drugs_data), "Drug data")
# Out:
# Loaded 9214 Drug data

# %%
# Skip if drug ID is already processed
processed_drug_ids = [drug["SFDA Drug ID"] for drug in all_drugs_data]
drug_ids = [drug_id for drug_id in drug_ids if drug_id not in processed_drug_ids]
print("Remaining", len(drug_ids), "Drug IDs")
# Out:
# Remaining 152 Drug IDs

# %%
# helper Function to save data to an Excel file
def save_data_to_excel(drugs_data):
    # Create DataFrame
    all_drugs_data_df = pd.DataFrame(drugs_data)
    # Save DataFrame to Excel file
    all_drugs_data_df.to_excel("drug_info.xlsx", index=False)
    print("Data saved to drug_info.xlsx")


# fetch drug information from the SDFA website
i = 0

for drug_id in tqdm(drug_ids):
    try:
        # print("Drug ID", drug_id)

        # Add the data to the list
        data = get_drug_info(drug_id)
        all_drugs_data.append(data)

        # Save data to file every 10 records
        i += 1
        if i % 10 == 0:
            save_data_to_excel(all_drugs_data)

    except Exception as e:
        print(f"Error processing drug ID {drug_id}: {e}")
        continue

# Save the data to an Excel file
save_data_to_excel(all_drugs_data)
# Out:
#   0%|          | 0/152 [00:00<?, ?it/s]
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx
# Data saved to drug_info.xlsx

# %%
# view DataFrame
pd.DataFrame(all_drugs_data)
# Out:
#      Registration Number Registration Year  \
# 0             1507245577            2024.0
# 1             1407245571            2024.0
# 2             1407245569            2024.0
# 3             1407245570            2024.0
# 4             1206245415               NaN
# ...                  ...               ...
# 9361          0202233207              2013
# 9362          0202233206              2013
# 9363           11-539-08              2008
# 9364          1005233628              2011
# 9365          1309234199              2011
#
#                                 Brand Name                   Generic Name  \
# 0                                 Rezurock           BELUMOSUDIL MESYLATE
# 1                                    Elbag            ELTROMBOPAG OLAMINE
# 2                                    Elbag            ELTROMBOPAG OLAMINE
# 3                             Omeprex Plus  OMEPRAZOLE,SODIUM BICARBONATE
# 4                                   Akeega          NIRAPARIB,ABIRATERONE
# ...                                    ...                            ...
# 9361                        AMLOR CAPS 5MG            AMLODIPINE BESILATE
# 9362                   AMLOR 10MG CAPSULES            AMLODIPINE BESILATE
# 9363            AMISTOP 5MG-5ML SUSPENSION                    DOMPERIDONE
# 9364   AMPIPLUS 1.5GM POWDER FOR INGECTION           AMPICILLIN,SULBACTAM
# 9365  AMOXIPLUS 1.2GM Powder for injection    AMOXICILLIN,CLAVULANIC ACID
#
#       Strength Unit Route of Administration  \
# 0          200   mg                Oral use
# 1           25   mg                Oral use
# 2           50   mg                Oral use
# 3      40,1100   mg                Oral use
# 4       50,500   mg                Oral use
# ...        ...  ...                     ...
# 9361         5   mg                Oral use
# 9362        10   mg                Oral use
# 9363       0.1                     Oral use
# 9364  1000,500   mg          Parenteral use
# 9365  1000,200    g          Parenteral use
#
#                             Dosage Form Package Size Package Types  ...  \
# 0                    Film-coated tablet           30        Bottle  ...
# 1                    Film-coated tablet           28       Blister  ...
# 2                    Film-coated tablet           28       Blister  ...
# 3                               Capsule           30       Blister  ...
# 4                    Film-coated tablet           56       Blister  ...
# ...                                 ...          ...           ...  ...
# 9361                      Capsule, hard           30       Blister  ...
# 9362                      Capsule, hard           30       Blister  ...
# 9363                         Suspension            1        Bottle  ...
# 9364  powder for solution for injection           50          Vial  ...
# 9365  powder for solution for injection           50          Vial  ...
#
#      Monitoring Status Drug Type Shelf Life (Months)       Storage Conditions  \
# 0         Uncontrolled       NCE                24.0  do not store above 30°c
# 1         Uncontrolled   Generic                24.0  do not store above 30°c
# 2         Uncontrolled   Generic                24.0  do not store above 30°c
# 3         Uncontrolled   Generic                24.0         store below 30°c
# 4         Uncontrolled       NCE                30.0         store below 30°c
# ...                ...       ...                 ...                      ...
# 9361      Uncontrolled       NCE                  48         store below 30°c
# 9362      Uncontrolled       NCE                  48         store below 30°c
# 9363      Uncontrolled   Generic                  24         store below 30°c
# 9364      Uncontrolled   Generic                  24         store below 25°c
# 9365      Uncontrolled   Generic                  24         store below 25°c
#
#      Public Price (SAR)                                   Manufacturer  \
# 0                   NaN                            UPM Pharmaceuticals
# 1                   NaN                            Synthon Hispania SL
# 2                   NaN                            Synthon Hispania SL
# 3                   NaN  SAJA-SAUDI ARABIAN JAPANESE PHARMACEUTICAL CO
# 4                   NaN                                        PATHEON
# ...                 ...                                            ...
# 9361                NaN                           PFIZER SAUDI LIMITED
# 9362                NaN                           PFIZER SAUDI LIMITED
# 9363                NaN                 DEEF PHARMACEUTICAL INDUSTRIES
# 9364                NaN                                 ANTIBIOTIC S.E
# 9365                NaN                                 ANTIBIOTIC S.E
#
#                                       Agent  \
# 0             Sanofi Arabia Trading Co. Ltd
# 1             SAJA Pharmaceutical Co., Ltd.
# 2             SAJA Pharmaceutical Co., Ltd.
# 3                Farouk, Maamoun Tamer & CO
# 4                             Cigalah Group
# ...                                     ...
# 9361                 Viatris Arabia Limited
# 9362                 Viatris Arabia Limited
# 9363                 DEEF MARKITING COMPANY
# 9364  AL HOBAIL MEDICAL OFFICE COMPANY LTD.
# 9365  AL HOBAIL MEDICAL OFFICE COMPANY LTD.
#
#                                   Marketing Company  \
# 0                         SANOFI WINTHROP INDUSTRIE
# 1     SAJA-SAUDI ARABIAN JAPANESE PHARMACEUTICAL CO
# 2     SAJA-SAUDI ARABIAN JAPANESE PHARMACEUTICAL CO
# 3     SAJA-SAUDI ARABIAN JAPANESE PHARMACEUTICAL CO
# 4                    Janssen-Cilag International NV
# ...                                             ...
# 9361                         Viatris Arabia Limited
# 9362                         Viatris Arabia Limited
# 9363                 DEEF PHARMACEUTICAL INDUSTRIES
# 9364                                 ANTIBIOTIC S.E
# 9365                                 ANTIBIOTIC S.E
#
#                                          SFDA Drug URL SFDA Drug ID
# 0     https://sdi.sfda.gov.sa/Home/Result?drugId=12641        12641
# 1     https://sdi.sfda.gov.sa/Home/Result?drugId=12635        12635
# 2     https://sdi.sfda.gov.sa/Home/Result?drugId=12634        12634
# 3     https://sdi.sfda.gov.sa/Home/Result?drugId=12633        12633
# 4     https://sdi.sfda.gov.sa/Home/Result?drugId=12579        12579
# ...                                                ...          ...
# 9361   https://sdi.sfda.gov.sa/Home/Result?drugId=3169         3169
# 9362   https://sdi.sfda.gov.sa/Home/Result?drugId=3170         3170
# 9363   https://sdi.sfda.gov.sa/Home/Result?drugId=3174         3174
# 9364   https://sdi.sfda.gov.sa/Home/Result?drugId=3189         3189
# 9365   https://sdi.sfda.gov.sa/Home/Result?drugId=3193         3193
#
# [9366 rows x 21 columns]
